# %%
import pandas as pd 
import numpy as np
sal=[24,35,56,78,89,91,83,78]
print(np.mean(sal))
# Out:
# 66.75

# %%
import pandas as pd 
import numpy as np

# %%
import pandas as pd
data=[20,47,50,65,87,98,100,120,112,750,170,69,75,87,94,56,68,45,68,57]
s=pd.Series(data)
print("Q1 =", s.quantile(0.25))
print("Q2 =", s.quantile(0.50))
print("Q3 =", s.quantile(0.75))
# Out:
# Q1 = 56.75
# Q2 = 72.0
# Q3 = 98.5

# %%
import numpy as np
df=[2,4,6,8,10,12,14,16]
Q1=np.quantile(df,0.25)
Q2=np.quantile(df,0.50)
Q3=np.quantile(df,0.75)
print(Q1,Q2,Q3)
Iqr=Q3-Q1
Iqr
# Out:
# 5.5 9.0 12.5
# np.float64(7.0)
